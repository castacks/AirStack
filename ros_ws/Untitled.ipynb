# %%
topics = [
"/robot_1/behavior/active_actions",
"/robot_1/behavior/arm_active",
"/robot_1/behavior/arm_commanded_success",
"/robot_1/behavior/arm_status",
"/robot_1/behavior/armed_success",
"/robot_1/behavior/auto_takeoff_commanded_success",
"/robot_1/behavior/behavior_tree_commands",
"/robot_1/behavior/behavior_tree_graphviz",
"/robot_1/behavior/behavior_tree_graphviz_compressed",
"/robot_1/behavior/disarm_active",
"/robot_1/behavior/disarm_commanded_success",
"/robot_1/behavior/disarm_status",
"/robot_1/behavior/explore_active",
"/robot_1/behavior/explore_commanded_success",
"/robot_1/behavior/explore_status",
"/robot_1/behavior/fixed_trajectory_commanded_success",
"/robot_1/behavior/follow_fixed_trajectory_active",
"/robot_1/behavior/follow_fixed_trajectory_status",
"/robot_1/behavior/has_control",
"/robot_1/behavior/is_armed",
"/robot_1/behavior/land_active",
"/robot_1/behavior/land_commanded_success",
"/robot_1/behavior/land_status",
"/robot_1/behavior/landed_success",
"/robot_1/behavior/offboard_commanded_success",
"/robot_1/behavior/offboard_mode_success",
"/robot_1/behavior/pause_active",
"/robot_1/behavior/pause_commanded_success",
"/robot_1/behavior/pause_status",
"/robot_1/behavior/request_control_active",
"/robot_1/behavior/request_control_status",
"/robot_1/behavior/rewind_active",
"/robot_1/behavior/rewind_commanded_success",
"/robot_1/behavior/rewind_status",
"/robot_1/behavior/stationary_success",
"/robot_1/behavior/takeoff_active",
"/robot_1/behavior/takeoff_commanded_success",
"/robot_1/behavior/takeoff_complete_success",
"/robot_1/behavior/takeoff_status",
"/robot_1/behavior_tree_commands",
"/robot_1/behavior_tree_graphviz",
"/robot_1/disparity",
"/robot_1/fixed_trajectory_command",
"/robot_1/global/world_model/scan_matched_points2",
"/robot_1/global/world_model/vdb_mapping/vdb_map_overwrites",
"/robot_1/global/world_model/vdb_mapping/vdb_map_pointcloud",
"/robot_1/global/world_model/vdb_mapping/vdb_map_sections",
"/robot_1/global/world_model/vdb_mapping/vdb_map_updates",
"/robot_1/global/world_model/vdb_mapping/vdb_map_visualization",
"/robot_1/global_plan_fixed_trajectory",
"/robot_1/interface/attitude_thrust_command",
"/robot_1/interface/cmd_attitude_thrust",
"/robot_1/interface/cmd_pose",
"/robot_1/interface/cmd_rate_thrust",
"/robot_1/interface/cmd_roll_pitch_yawrate_thrust",
"/robot_1/interface/cmd_torque_thrust",
"/robot_1/interface/cmd_velocity",
"/robot_1/interface/has_control",
"/robot_1/interface/is_armed",
"/robot_1/interface/mavros/setpoint_position/local",
"/robot_1/interface/mavros/setpoint_raw/attitude",
"/robot_1/interface/mavros/state",
"/robot_1/interface/pose_command",
"/robot_1/interface/rate_thrust_command",
"/robot_1/interface/roll_pitch_yawrate_thrust_command",
"/robot_1/interface/torque_thrust_command",
"/robot_1/interface/tracking_point",
"/robot_1/interface/velocity_command",
"/robot_1/left/image_rect",
"/robot_1/local/controls/closest_point",
"/robot_1/local/controls/look_ahead",
"/robot_1/local/controls/odometry",
"/robot_1/local/controls/tracking_error",
"/robot_1/local/controls/tracking_point",
"/robot_1/local/controls/tracking_point_velocity_magnitude",
"/robot_1/local/controls/traj_drone_point",
"/robot_1/local/controls/trajectory",
"/robot_1/local/controls/trajectory_completion_percentage",
"/robot_1/local/controls/trajectory_controller_debug_markers",
"/robot_1/local/controls/trajectory_segment",
"/robot_1/local/controls/trajectory_segment_vis",
"/robot_1/local/controls/trajectory_time",
"/robot_1/local/controls/trajectory_track",
"/robot_1/local/controls/trajectory_vis",
"/robot_1/local/controls/virtual_tracking_point",
"/robot_1/local/planning/ekf_active",
"/robot_1/local/planning/fixed_trajectory_command",
"/robot_1/local/planning/high_takeoff",
"/robot_1/local/planning/landing_state",
"/robot_1/local/planning/odometry",
"/robot_1/local/planning/takeoff_state",
"/robot_1/local/planning/tracking_point",
"/robot_1/local/planning/trajectory_completion_percentage",
"/robot_1/local/planning/trajectory_track",
"/robot_1/local/world_model/camera_info",
"/robot_1/local/world_model/depth",
"/robot_1/local/world_model/expanded_disparity_bg",
"/robot_1/local/world_model/expanded_disparity_fg",
"/robot_1/local/world_model/expansion_cloud",
"/robot_1/local/world_model/expansion_poly",
"/robot_1/odometry",
"/robot_1/perception/depth/disparity",
"/robot_1/perception/depth/left/camera_info",
"/robot_1/perception/depth/left/image_rect",
"/robot_1/perception/depth/right/camera_info",
"/robot_1/perception/depth/right/image_rect",
"/robot_1/perception/state_estimation/mavros/local_position/odom",
"/robot_1/perception/state_estimation/odometry",
"/robot_1/trajectory_controller_debug_markers",
"/robot_1/trajectory_segment_vis",
"/robot_1/trajectory_vis"
]

# %%
a = sorted(topics, key=lambda x: x[::-1])

# %%
a
# Out:
# ['/robot_1/global/world_model/scan_matched_points2',
#  '/robot_1/local/controls/look_ahead',
#  '/robot_1/interface/is_armed',
#  '/robot_1/behavior/is_armed',
#  '/robot_1/behavior/behavior_tree_graphviz_compressed',
#  '/robot_1/interface/pose_command',
#  '/robot_1/interface/attitude_thrust_command',
#  '/robot_1/interface/rate_thrust_command',
#  '/robot_1/interface/roll_pitch_yawrate_thrust_command',
#  '/robot_1/interface/torque_thrust_command',
#  '/robot_1/fixed_trajectory_command',
#  '/robot_1/local/planning/fixed_trajectory_command',
#  '/robot_1/interface/velocity_command',
#  '/robot_1/local/world_model/expansion_cloud',
#  '/robot_1/global/world_model/vdb_mapping/vdb_map_pointcloud',
#  '/robot_1/local/controls/tracking_point_velocity_magnitude',
#  '/robot_1/interface/mavros/setpoint_raw/attitude',
#  '/robot_1/local/planning/trajectory_completion_percentage',
#  '/robot_1/local/controls/trajectory_completion_percentage',
#  '/robot_1/local/controls/trajectory_time',
# ...
